# %%
# !mkdir topsis-Mansehaj-102303544
# !mkdir topsis-Mansehaj-102303544/topsis

# %%
# %%writefile topsis-Mansehaj-102303544/topsis/__init__.py
# Out:
# Writing topsis-Mansehaj-102303544/topsis/__init__.py

# %%
# %%writefile topsis-Mansehaj-102303544/topsis/topsis.py
import sys
import pandas as pd
import numpy as np
import os

def main():
    if len(sys.argv) != 5:
        print("Usage: topsis <input_file> <weights> <impacts> <output_file>")
        sys.exit(1)

    input_file = sys.argv[1]
    weights = list(map(float, sys.argv[2].split(",")))
    impacts = sys.argv[3].split(",")
    output_file = sys.argv[4]

    if not os.path.isfile(input_file):
        print("File not found")
        sys.exit(1)

    data = pd.read_csv(input_file)
    criteria = data.iloc[:, 1:].astype(float)

    norm = criteria / np.sqrt((criteria**2).sum())
    weighted = norm * weights

    best, worst = [], []
    for i in range(len(impacts)):
        if impacts[i] == '+':
            best.append(weighted.iloc[:, i].max())
            worst.append(weighted.iloc[:, i].min())
        else:
            best.append(weighted.iloc[:, i].min())
            worst.append(weighted.iloc[:, i].max())

    best = np.array(best)
    worst = np.array(worst)

    d_best = np.sqrt(((weighted - best) ** 2).sum(axis=1))
    d_worst = np.sqrt(((weighted - worst) ** 2).sum(axis=1))

    score = d_worst / (d_best + d_worst)

    data["Topsis Score"] = score
    data["Rank"] = data["Topsis Score"].rank(ascending=False).astype(int)
    data.to_csv(output_file, index=False)

if __name__ == "__main__":
    main()
# Out:
# Writing topsis-Mansehaj-102303544/topsis/topsis.py

# %%
# %%writefile topsis-Mansehaj-102303544/setup.py
from setuptools import setup, find_packages

setup(
    name="topsis-Mansehaj-102303544",
    version="1.0.0",
    author="Mansehaj",
    description="TOPSIS implementation as a Python package",
    packages=find_packages(),
    install_requires=["pandas", "numpy"],
    entry_points={
        "console_scripts": [
            "topsis=topsis.topsis:main"
        ]
    },
)
# Out:
# Writing topsis-Mansehaj-102303544/setup.py

# %%
# %%writefile topsis-Mansehaj-102303544/pyproject.toml
# [build-system]
# requires = ["setuptools", "wheel"]
# build-backend = "setuptools.build_meta"
# Out:
# Writing topsis-Mansehaj-102303544/pyproject.toml

# %%
# %%writefile topsis-Mansehaj-102303544/README.md
# # TOPSIS Python Package
#
# ## Installation
# pip install topsis-Mansehaj-102303544
#
# ## Usage
# topsis data.csv "1,1,1,1,1" "+,+,-,+,+" output.csv
# Out:
# Writing topsis-Mansehaj-102303544/README.md

# %%
# !pip install build twine
# Out:
# Collecting build
#   Downloading build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting twine
#   Downloading twine-6.2.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build) (25.0)
# Collecting pyproject_hooks (from build)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting readme-renderer>=35.0 (from twine)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from twine) (2.32.4)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from twine) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from twine) (2.5.0)
# Requirement already satisfied: keyring>=21.2.0 in /usr/local/lib/python3.12/dist-packages (from twine) (25.7.0)
# Collecting rfc3986>=1.4.0 (from twine)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from twine) (13.9.4)
# Collecting id (from twine)
#   Downloading id-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=21.2.0->twine) (6.0.2)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine)
#   Downloading nh3-0.3.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: docutils>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from readme-renderer>=35.0->twine) (0.21.2)
# Requirement already satisfied: Pygments>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from readme-renderer>=35.0->twine) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->twine) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->twine) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->twine) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->twine) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine) (0.1.2)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=21.2.0->twine) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=21.2.0->twine) (10.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->twine) (2.23)
# Downloading build-1.4.0-py3-none-any.whl (24 kB)
# Downloading twine-6.2.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.5 MB/s eta 0:00:00
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading id-1.5.0-py3-none-any.whl (13 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading nh3-0.3.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (797 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 kB 14.7 MB/s eta 0:00:00
# Installing collected packages: rfc3986, pyproject_hooks, nh3, readme-renderer, id, build, twine
# Successfully installed build-1.4.0 id-1.5.0 nh3-0.3.2 pyproject_hooks-1.2.0 readme-renderer-44.0 rfc3986-2.0.0 twine-6.2.0

# %%
# !cd topsis-Mansehaj-102303544 && python -m build
# Out:
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
#   - wheel
# * Getting build dependencies for sdist...
# running egg_info
# creating topsis_Mansehaj_102303544.egg-info
# writing topsis_Mansehaj_102303544.egg-info/PKG-INFO
# writing dependency_links to topsis_Mansehaj_102303544.egg-info/dependency_links.txt
# writing entry points to topsis_Mansehaj_102303544.egg-info/entry_points.txt
# writing requirements to topsis_Mansehaj_102303544.egg-info/requires.txt
# writing top-level names to topsis_Mansehaj_102303544.egg-info/top_level.txt
# writing manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# reading manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# writing manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing topsis_Mansehaj_102303544.egg-info/PKG-INFO
# writing dependency_links to topsis_Mansehaj_102303544.egg-info/dependency_links.txt
# writing entry points to topsis_Mansehaj_102303544.egg-info/entry_points.txt
# writing requirements to topsis_Mansehaj_102303544.egg-info/requires.txt
# writing top-level names to topsis_Mansehaj_102303544.egg-info/top_level.txt
# reading manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# writing manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# running check
# creating topsis_mansehaj_102303544-1.0.0
# creating topsis_mansehaj_102303544-1.0.0/topsis
# creating topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying files to topsis_mansehaj_102303544-1.0.0...
# copying README.md -> topsis_mansehaj_102303544-1.0.0
# copying pyproject.toml -> topsis_mansehaj_102303544-1.0.0
# copying setup.py -> topsis_mansehaj_102303544-1.0.0
# copying topsis/__init__.py -> topsis_mansehaj_102303544-1.0.0/topsis
# copying topsis/topsis.py -> topsis_mansehaj_102303544-1.0.0/topsis
# copying topsis_Mansehaj_102303544.egg-info/PKG-INFO -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying topsis_Mansehaj_102303544.egg-info/SOURCES.txt -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying topsis_Mansehaj_102303544.egg-info/dependency_links.txt -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying topsis_Mansehaj_102303544.egg-info/entry_points.txt -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying topsis_Mansehaj_102303544.egg-info/requires.txt -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying topsis_Mansehaj_102303544.egg-info/top_level.txt -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# copying topsis_Mansehaj_102303544.egg-info/SOURCES.txt -> topsis_mansehaj_102303544-1.0.0/topsis_Mansehaj_102303544.egg-info
# Writing topsis_mansehaj_102303544-1.0.0/setup.cfg
# Creating tar archive
# removing 'topsis_mansehaj_102303544-1.0.0' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
#   - wheel
# * Getting build dependencies for wheel...
# running egg_info
# writing topsis_Mansehaj_102303544.egg-info/PKG-INFO
# writing dependency_links to topsis_Mansehaj_102303544.egg-info/dependency_links.txt
# writing entry points to topsis_Mansehaj_102303544.egg-info/entry_points.txt
# writing requirements to topsis_Mansehaj_102303544.egg-info/requires.txt
# writing top-level names to topsis_Mansehaj_102303544.egg-info/top_level.txt
# reading manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# writing manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/topsis
# copying topsis/topsis.py -> build/lib/topsis
# copying topsis/__init__.py -> build/lib/topsis
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/topsis
# copying build/lib/topsis/topsis.py -> build/bdist.linux-x86_64/wheel/./topsis
# copying build/lib/topsis/__init__.py -> build/bdist.linux-x86_64/wheel/./topsis
# running install_egg_info
# running egg_info
# writing topsis_Mansehaj_102303544.egg-info/PKG-INFO
# writing dependency_links to topsis_Mansehaj_102303544.egg-info/dependency_links.txt
# writing entry points to topsis_Mansehaj_102303544.egg-info/entry_points.txt
# writing requirements to topsis_Mansehaj_102303544.egg-info/requires.txt
# writing top-level names to topsis_Mansehaj_102303544.egg-info/top_level.txt
# reading manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# writing manifest file 'topsis_Mansehaj_102303544.egg-info/SOURCES.txt'
# Copying topsis_Mansehaj_102303544.egg-info to build/bdist.linux-x86_64/wheel/./topsis_Mansehaj_102303544-1.0.0-py3.12.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/topsis_mansehaj_102303544-1.0.0.dist-info/WHEEL
# creating '/content/topsis-Mansehaj-102303544/dist/.tmp-fdb8wjel/topsis_mansehaj_102303544-1.0.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'topsis/__init__.py'
# adding 'topsis/topsis.py'
# adding 'topsis_mansehaj_102303544-1.0.0.dist-info/METADATA'
# adding 'topsis_mansehaj_102303544-1.0.0.dist-info/WHEEL'
# adding 'topsis_mansehaj_102303544-1.0.0.dist-info/entry_points.txt'
# adding 'topsis_mansehaj_102303544-1.0.0.dist-info/top_level.txt'
# adding 'topsis_mansehaj_102303544-1.0.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built topsis_mansehaj_102303544-1.0.0.tar.gz and topsis_mansehaj_102303544-1.0.0-py3-none-any.whl

# %%
# %%writefile data.csv
# Fund Name,P1,P2,P3,P4,P5
# M1,0.67,0.45,6.5,42.6,12.56
# M2,0.6,0.36,3.6,53.3,14.47
# M3,0.82,0.67,3.8,63.1,17.1
# M4,0.6,0.36,3.5,69.2,18.42
# M5,0.76,0.58,4.8,43,12.29
# M6,0.69,0.48,6.6,48.7,14.12
# M7,0.79,0.62,4.8,59.2,16.35
# M8,0.84,0.71,6.5,34.5,10.64
# Out:
# Writing data.csv

# %%
# %%writefile ~/.pypirc
# [distutils]
# index-servers =
#     pypi
#
# [pypi]
# repository = https://upload.pypi.org/legacy/
# username = __token__
# password = pypi-XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# ## PyPI Upload (Security Note)
#
# The PyPI API token was used locally in Google Colab for uploading the package.
# For security reasons, the token has been revoked and is not included in this repository.
# Out:
# Writing /root/.pypirc

# %%
# !cat ~/.pypirc
# Out:
# [distutils]
# index-servers =
#     pypi
#
# [pypi]
# repository = https://upload.pypi.org/legacy/
# username = __token__
# password = pypi-AgEIcHlwaS5vcmcCJGIyZWZkODdmLWQ4MzMtNDdkOS1iZTI3LTYzOWIwNjU5ODk5ZgACKlszLCI5NDAwZmE3OS02ZWU0LTQ3YWMtODc1YS1lODkwNmRjZDlhYzAiXQAABiCkirK5V8PoC07-Rku0m3ObZMFlpf2EDNHRfrpD5IyFaw

# %%
# !cd topsis-Mansehaj-102303544 && twine upload dist/*
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading topsis_mansehaj_102303544-1.0.0-py3-none-any.whl
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 kB • 00:00 • ?
# Uploading topsis_mansehaj_102303544-1.0.0.tar.gz
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 kB • 00:00 • ?
#
# View at:
# https://pypi.org/project/topsis-Mansehaj-102303544/1.0.0/

# %%
# !pip install topsis-Mansehaj-102303544
# Out:
# Requirement already satisfied: topsis-Mansehaj-102303544 in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from topsis-Mansehaj-102303544) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from topsis-Mansehaj-102303544) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->topsis-Mansehaj-102303544) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->topsis-Mansehaj-102303544) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->topsis-Mansehaj-102303544) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->topsis-Mansehaj-102303544) (1.17.0)

# %%
# !topsis data.csv "1,1,1,1,1" "+,+,-,+,+" output.csv

# %%
# !cat output.csv
# Out:
# Fund Name,P1,P2,P3,P4,P5,Topsis Score,Rank
# M1,0.67,0.45,6.5,42.6,12.56,0.21516477957939756,8
# M2,0.6,0.36,3.6,53.3,14.47,0.4680077217192938,4
# M3,0.82,0.67,3.8,63.1,17.1,0.8614812347511583,1
# M4,0.6,0.36,3.5,69.2,18.42,0.5885473629444463,3
# M5,0.76,0.58,4.8,43.0,12.29,0.4507535668101614,5
# M6,0.69,0.48,6.6,48.7,14.12,0.326624234590125,7
# M7,0.79,0.62,4.8,59.2,16.35,0.6954636499145801,2
# M8,0.84,0.71,6.5,34.5,10.64,0.41415102365682993,6
